# %%
import sys
sys.path.insert(0, 'src')
from forecasting import preview_forecasts

# See all forecasts
preview_forecasts()

# See just Yam forecasts
preview_forecasts(commodity_name="Yam")

# See just Lagos forecasts
preview_forecasts(state_name="Lagos")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import sys
#       2 sys.path.insert(0, 'src')
# ----> 3 from forecasting import preview_forecasts
#       5 # See all forecasts
#       6 preview_forecasts()
#
# ModuleNotFoundError: No module named 'forecasting'
